# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------- ----------------------- 5.2/12.6 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 32.8 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
# !pip install pyarrow fastparquet
# Out:
# ...
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# ...
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    - -------------------------------------- 1.0/25.1 MB 12.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.8/25.1 MB 22.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.9/25.1 MB 27.3 MB/s eta 0:00:01
#    --------------------------------- ------ 21.0/25.1 MB 30.1 MB/s eta 0:00:01
#    ---------------------------------------  24.9/25.1 MB 30.3 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 26.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/673.0 kB ? eta -:--:--
#    --------------------------------------- 673.0/673.0 kB 25.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 44.6 MB/s eta 0:00:00
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# ...

# %%
import pandas as pd
df_examples = pd.read_parquet('shopping_queries_dataset_examples.parquet')
df_products = pd.read_parquet('shopping_queries_dataset_products.parquet')
df_sources = pd.read_csv("shopping_queries_dataset_sources.csv")

# %%
df_examples
# Out:
#          example_id                     query  query_id  product_id  \
# 0                 0             revent 80 cfm         0  B000MOO21W
# 1                 1             revent 80 cfm         0  B07X3Y6B1V
# 2                 2             revent 80 cfm         0  B07WDM7MQQ
# 3                 3             revent 80 cfm         0  B07RH6Z8KW
# 4                 4             revent 80 cfm         0  B07QJ7WYFQ
# ...             ...                       ...       ...         ...
# 2621283     2621283  �����j�[�h�p�[�x abrasus    130651  B0063ASUY4
# 2621284     2621284  �����j�[�h�p�[�x abrasus    130651  B0062EZYIG
# 2621285     2621285  �����j�[�h�p�[�x abrasus    130651  B07H8MWBZN
# 2621286     2621286  �����j�[�h�p�[�x abrasus    130651  B00IZH4T9S
# 2621287     2621287  �����j�[�h�p�[�x abrasus    130651  B07R536DG1
#
#         product_locale esci_label  small_version  large_version  split
# 0                   us          I              0              1  train
# ...

# %%
df_examples[df_examples['query_id'] == 1]
# Out:
#     example_id                         query  query_id  product_id  \
# 16          16  !awnmower tires without rims         1  B075SCHMPY
# 17          17  !awnmower tires without rims         1  B08L3B9B9P
# 18          18  !awnmower tires without rims         1  B082K7V2GZ
# 19          19  !awnmower tires without rims         1  B07P4CF3DP
# 20          20  !awnmower tires without rims         1  B07C1WZG12
# 21          21  !awnmower tires without rims         1  B077QMNXTS
# 22          22  !awnmower tires without rims         1  B01M3SJ699
# 23          23  !awnmower tires without rims         1  B06XX6BM2R
# 24          24  !awnmower tires without rims         1  B01DBGLLUC
# 25          25  !awnmower tires without rims         1  B00N16T5D8
# 26          26  !awnmower tires without rims         1  B0089RNSNM
# 27          27  !awnmower tires without rims         1  B0089RA0HY
# 28          28  !awnmower tires without rims         1  B005O5Y3QI
# ...

# %%
df_examples["query"].unique()[:15]
# Out:
# array([' revent 80 cfm', '!awnmower tires without rims',
#        '!qscreen fence without holes', '!solid camiseta sin manga',
#        '"vitamina c"', '# 10 self-seal envelopes without window',
#        '# 2 pencils not sharpened', '# cellist thats not a hashtag',
#        '# do not disturb', '# mom life', '# sharp not hashtag shirt',
#        '#1 best and not expensive bath back brush cream color',
#        '#1 black natural hair dye without ammonia or peroxide',
#        '#1 rated resveratrol supplement without tea leaves',
#        '#1 selling shoes for men without shoeleases'], dtype=object)

# %%
df_examples[df_examples['product_locale'] == "jp"][::50]
# Out:
#          example_id                                              query  \
# 3502           3502                                         &ハニー シャンプー
# 5713           5713  (マックバースト） mach burst 軽い コンフォート 穴開き スポーツ サドル 痛く...
# 5763           5763                             (知っていることはあまりないけれど)家族です
# 8778           8778                                        - ビニール手袋粉なし
# 9192           9192               -アンソロジー 乙女ゲームの破滅フラグしかない悪役令嬢に転生してしまった
# ...             ...                                                ...
# 2621085     2621085                                       ﾃｨファール 電気ケトル
# 2621135     2621135                                       ﾈｰﾑ キーホルダー 子
# 2621185     2621185                                         ﾎｯﾄサンドメーカー
# 2621235     2621235                                            ﾏｼﾞｯｸﾘﾝ
# 2621285     2621285                           �����j�[�h�p�[�x abrasus
#
#          query_id  product_id product_locale esci_label  small_version  \
# ...

# %%
df_products
# Out:
#          product_id                                      product_title  \
# 0        B079VKKJN7  11 Degrees de los Hombres Playera con Logo, Ne...
# 1        B079Y9VRKS          Camiseta Eleven Degrees Core TS White (M)
# 2        B07DP4LM9H  11 Degrees de los Hombres Core Pull Over Hoodi...
# 3        B07G37B9HP          11 Degrees Poli Panel Track Pant XL Black
# 4        B07LCTGDHY  11 Degrees Gorra Trucker Negro OSFA (Talla úni...
# ...             ...                                                ...
# 1814919  B09FJYBVKS  スポーツブラ 揺れない ヨガウェア レディース トップス 通気性 ナイトブラ スポーツブラジ...
# 1814920  B09FTJ3S1N  ブラジャー レディース 補正ブラ Gabrioir 揺れない 大きいサイズ バストアップ美胸...
# 1814921  B09G72LDQZ  レディース ブラジャー 補正ブラ トップス Gabrioir 大きいサイズ 揺れない 脇高設...
# 1814922  B09GBGRTPB  ナイトブラ ノンワイヤーブラ ブラジャー レディース Gabrioir 大きいサイズ パット...
# 1814923  B09GBKN83Q  インナーキャミソール レディース ブラトップ キャミソール Gabrioir ノーワイヤー ...
#
#                                        product_description  \
# ...

# %%
df_products[df_products["product_id"] == "B08L3B9B9P"].values
# Out:
# array([['B08L3B9B9P',
#         'MaxAuto 2-Pack 13x5.00-6 2PLY Turf Mower Tractor Tire with Yellow Rim, (3" Centered Hub, 3/4" Bushings )',
#         'MaxAuto 2-Pack 13x5.00-6 2PLY Turf Mower Tractor Tire with Yellow Rim, 3" Centered Hub, 3/4" Bearings<br>',
#         'Please check your existing tire Sidewall for tire, hub and Bushing size to ensure proper replacement fit.\n3" Centered Hub(two sides symmetrical);3/4" Bushings;300 lb load capacity.\nTire size:13x5.00-6;Tire Type:Pneumatic Tires;Tire Diameter inch:13.09";Tire Width inch:4.56";Load Capacity:300lbs\nRim Diameter:6";Bearing size:3/4";Hub Length:3" Centered Hub with grease fitting\nPopular Applications：Wheelbarrows,Garden carts,Hand trucks,Pressure washers,Generators,Air compressors,Lawn mower and other types of outdoor power equipment.',
#         'MaxAuto', None, 'us']], dtype=object)
