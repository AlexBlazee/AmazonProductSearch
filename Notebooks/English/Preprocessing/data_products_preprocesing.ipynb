# %%
import os
root_dir_name = 'AmazonProductSearch'
curr_dir = os.getcwd()
root_dir = curr_dir[:curr_dir.index(root_dir_name) + len(root_dir_name)]
dataset_dir = os.path.join(root_dir , 'Dataset')
en_dataset_dir = os.path.join(dataset_dir ,'English')
embed_dir = os.path.join(root_dir , 'embedder')
saved_embed_dir = os.path.join(root_dir , 'embedder' , 'saved')

# %%
#! pip install pyarrow fastparquet
import pandas as pd
df_products = pd.read_parquet( os.path.join( dataset_dir , 'shopping_queries_dataset_products.parquet'))
# df_queries = pd.read_parquet('shopping_queries_dataset_examples.parquet')

# %% [markdown]
# # data sampling and cleaning

# %%
df_products = df_products[df_products['product_locale'] == 'us']

# %%
import numpy as np
df_products.replace('N/A', np.nan, inplace=True)
df_products.replace('"N/A"', np.nan, inplace=True)

# %%
df_products['product_title'].isna().sum() , df_products['product_description'].isna().sum() , df_products['product_bullet_point'].isna().sum(), df_products['product_brand'].isna().sum()\
, df_products['product_color'].isna().sum() ,  df_products['product_locale'].isna().sum()
# Out:
# (0, 569792, 178776, 72361, 406104, 0)

# %%
# dropping of any row that have none values
df_filtered = df_products.dropna()

# %%
df_filtered
# Out:
#          product_id                                      product_title  \
# 167175   B07RH6Z8KW  Delta Electronics RAD80L BreezRadiance 80 CFM ...
# 167178   B075VXJ9VG  BAZIC Pencil #2 HB Pencils, Latex Free Eraser,...
# 167179   B07G7F6JZ6  Emraw Pre Sharpened Round Primary Size No 2 Ju...
# 167184   B087J9MBXJ  YOTINO Pre-sharpened Wood Cased #2 HB Pencils ...
# 167187   B08R8LW1W2  HB pencils with eraser set 12 pack + 2 Erasers...
# ...             ...                                                ...
# 1753344  B087B9YQ6S  MIER Men's Outdoor Performance Tactical Polo S...
# 1753346  B08TN1F42D  Mens Golf Shirt Moisture Wicking Quick Dry Sho...
# 1753347  B08XX3NL14  SAYFINE 5 Pack Plain Atheletic Shirts for Men,...
# 1753350  B096RXY1VT  Casei Womens Polo Shirts Golf Shirts Quick Dry...
# 1753351  B09BW3YVP8  Men Golf Performance Shirt Moisture Wicking Lo...
#
#                                        product_description  \
# 167175   This pre-owned or refurbished product has been...
# 167178   <p><strong>BACK TO BAZIC</strong></p><p>Our go...
# 167179   <p><b>Emraw Pre-Sharpened #2 HB Wood Pencils -...
# 167184   </br>YOTINO Pre-sharpened #2 HB Pencils Pack o...
# 167187   <b>We made sure that we used high quality mate...
# ...                                                    ...
# 1753344  MIER men's performance short/long polo shirt p...
# 1753346  <p><b>Markalar Men's Classic Quick Drying Golf...
# 1753347  <b>SAYFINE MENS T SHIRTS & GYM T SHIRTS & WORK...
# 1753350  black friday deals 2021 gifts for men gifts fo...
# 1753351  Golf/Tennis has to be one of the most stylish ...
#
#                                       product_bullet_point  \
# 167175   Quiet operation at 1.5 sones\nBuilt-in thermos...
# 167178   &#11088; UN-SHARPENED #2 PREMIUM PENCILS. Each...
# 167179   ✓ PACK OF 8 NUMBER 2 PRESHARPENED BEGINNERS PE...
# 167184   Convenient Bulk Pack - Box of 100 count #2 HB ...
# 167187   Value For Money:Suitable for Kids school penci...
# ...                                                    ...
# 1753344  MIER men's long and short sleeve polo shirt fe...
# 1753346  Quiky dry and Breathable Fabric：Our Mens Golf ...
# 1753347  [VALUE PACK] - Athletic crew neck and flat-loc...
# 1753350  【Quick Dry & Moisture Wicking】Womens polo shir...
# 1753351  ➤PERFORMANCE FABRIC: Lightweight and Breathabl...
#
#                              product_brand          product_color  \
# 167175   DELTA ELECTRONICS (AMERICAS) LTD.                  White
# 167178                      BAZIC Products               12-count
# 167179                               Emraw                 Yellow
# 167184                                  N2                 Yellow
# 167187                               VICGP                  Green
# ...                                    ...                    ...
# 1753344                               MIER  Black01- Short Sleeve
# 1753346                             SAMERM                  Navy7
# 1753347                            SAYFINE         Black (5 Pack)
# 1753350                              Casei                  White
# 1753351                         JACK SMITH                    Red
#
#         product_locale
# 167175              us
# 167178              us
# 167179              us
# 167184              us
# 167187              us
# ...                ...
# 1753344             us
# 1753346             us
# 1753347             us
# 1753350             us
# 1753351             us
#
# [437953 rows x 7 columns]

# %%
a = df_products['product_brand'].value_counts().keys()
b = df_filtered['product_brand'].value_counts().keys() # list of brand names
missing_brands = []
for x in a:
    if x not in b: 
        missing_brands.append(x)
print(f"{len(missing_brands)} brand's with {len(df_products[df_products['product_brand'].isin(missing_brands)])} have been completely removed to reduce the size")
# Out:
# 95196 brand's with 294188 have been completely removed to reduce the size

# %%
df_filtered[df_filtered['product_brand']=='Nike']
# Out:
#          product_id                                      product_title  \
# 172911   B00BUBPF3U  Nike Jr. Mercurial Victory VI FG Soccer Cleats...
# 172921   B07FKCR2GY                                Jr Legend 7 Club FG
# 172923   B07MKRTM58  Nike Jr Tiempo Legend 8 Club FG/MG Youth Socce...
# 183213   B071XLRFBC  Nike Men's Rise 365 Breathe Running Top-Black-...
# 183218   B07D38FX6J  Nike Men's Dry Miler Running Top Shortsleeve (...
# ...             ...                                                ...
# 1747075  B07TMQX9L9  Nike Womens Air Max Bella Tr 3 Womens Trainini...
# 1747079  B07YK4LS8V  Nike Air Zoom Vomero 14 Women's Running Shoe P...
# 1747080  B07YK4YH2Z  Nike Air Zoom Vomero 14 Women's Running Shoe P...
# 1747081  B085RK5G1C  Nike Joyride Run Flyknit Women's Running Shoe ...
# 1747083  B08FB8NJGV  Nike Women's Joyride Dual Run Running Shoes (F...
#
#                                        product_description  \
# 172911   Lightweight cleat for the ideal combo of speed...
# 172921   There's beauty in simplicity, and when your at...
# 172923   The Jr. Tiempo Legend 8 Club MG takes the touc...
# 183213   Nike Men's Rise 365 Breathe Running Top<br><br...
# 183218   Essential for beginners and elites, the Nike M...
# ...                                                    ...
# 1747075  Lift and work out with the best of them with t...
# 1747079  The Nike Air Zoom Vomero 14 Women's Running Sh...
# 1747080  The Nike Air Zoom Vomero 14 Women's Running Sh...
# 1747081  Nike shoes are the foundation of the sneaker c...
# 1747083  <p>Nike Women's Joyride Dual Run Running Shoes...
#
#                                       product_bullet_point product_brand  \
# 172911   Lightweight cleat for the ideal combo of speed...          Nike
# 172921   Accommodating shape provides a comfortable, ve...          Nike
# 172923   Soft synthetic leather wraps your foot for com...          Nike
# 183213   Rib crewneck Standard Fit tee\nDri-Fit to help...          Nike
# 183218   Nike Breathe fabric offers breathability.\nDri...          Nike
# ...                                                    ...           ...
# 1747075  Style#: CJ0842-600\nInner sleeve delivers a se...          Nike
# 1747079  Full-length Zoom Air unit gives a smooth, snap...          Nike
# 1747080  Full-length Zoom Air unit gives a smooth, snap...          Nike
# 1747081            Nike\nWomens Shoes\nFire Pink/Vast Grey          Nike
# 1747083  Small foam beads are contained in 2 compartmen...          Nike
#
#                                              product_color product_locale
# 172911                                            Obsidian             us
# 172921                                               Black             us
# 172923                                               Black             us
# 183213                                               Black             us
# 183218                                Light Pumice/Heather             us
# ...                                                    ...            ...
# 1747075               Cosmic Fuchsia/Black-pistachio Frost             us
# 1747079  Multicolour Pink Blast Black True Berry White 602             us
# 1747080  Multicolour Pink Blast Black True Berry White 602             us
# 1747081            Fire Pink/Vast Grey-laser Crimson-white             us
# 1747083                            Fire Pink Vast Grey 603             us
#
# [2401 rows x 7 columns]

# %%
df_filtered.to_parquet(os.path.join(en_dataset_dir , 'en_reduced_products_dataset.parquet' ) )

# %% [markdown]
# # data preprocesing for temporary data

# %%
import pandas as pd
df_filtered = pd.read_parquet(os.path.join(en_dataset_dir , 'en_reduced_products_dataset.parquet' ))

# %%
from bs4 import BeautifulSoup
import re
import pandas as pd

# Initialize html2text converter


def remove_emojis(text):
    # Define a regex pattern to match emojis
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
        "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
        "\U0001F700-\U0001F77F"  # Alchemical Symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"  # Enclosed characters
        "]+", flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

def clean_text(text):
    if pd.isna(text):
        return ""
        
    # Remove any remaining HTML tags (as a fallback)
    soup = BeautifulSoup(text, "html.parser")
    text = soup.get_text(separator=" ", strip=True)
    text = remove_emojis(text)
    # Remove special characters, URLs, and extra whitespace
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'[^\w\s]', ' ', text)  # Remove special characters
    text = re.sub(r'\s+', ' ', text).strip()  # Normalize whitespace
    return text

def preprocess_data(df):
    # Clean text columns
    text_columns = ['product_title', 'product_description', 'product_bullet_point', 'product_brand']
    
    for col in text_columns:
        df[col] = df[col].apply(clean_text)
    
    # Merge relevant columns
    df['merged_text'] = df[['product_title', 'product_description', 'product_bullet_point', 
                            'product_brand', 'product_color', 'product_locale']].apply(
        lambda x: ' '.join(str(val) for val in x if pd.notna(val)), axis=1
    )
    
    df['merged_metadata'] = df[['product_title','product_brand', 'product_color', 'product_locale']].apply(
        lambda x: ' '.join(str(val) for val in x if pd.notna(val)), axis=1
    )


    # Create metadata column
    df['metadata'] = df.apply(lambda row: {
        'product_id': row['product_id'],
        'title': row['product_title'],
        'brand': row['product_brand'],
        'color': row['product_color'],
        'locale': row['product_locale']
    }, axis=1)

    # Select only relevant columns
    return df

# %%
df = preprocess_data(df_filtered)
# Out:
# C:\Users\prade\AppData\Local\Temp\ipykernel_39636\696395028.py:32: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# C:\Users\prade\AppData\Local\Temp\ipykernel_39636\696395028.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(clean_text)
# C:\Users\prade\AppData\Local\Temp\ipykernel_39636\696395028.py:32: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# C:\Users\prade\AppData\Local\Temp\ipykernel_39636\696395028.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['merged_text'] = df[['product_title', 'product_description', 'product_bullet_point',
# C:\Users\prade\AppData\Local\Temp\ipykernel_39636\696395028.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['merged_metadata'] = df[['product_title','product_brand', 'product_color', 'product_locale']].apply(
# C:\Users\prade\AppData\Local\Temp\ipykernel_39636\696395028.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['metadata'] = df.apply(lambda row: {

# %%
df
# Out:
#          product_id                                      product_title  \
# 167175   B07RH6Z8KW  Delta Electronics RAD80L BreezRadiance 80 CFM ...
# 167178   B075VXJ9VG  BAZIC Pencil 2 HB Pencils Latex Free Eraser Wo...
# 167179   B07G7F6JZ6  Emraw Pre Sharpened Round Primary Size No 2 Ju...
# 167184   B087J9MBXJ  YOTINO Pre sharpened Wood Cased 2 HB Pencils B...
# 167187   B08R8LW1W2  HB pencils with eraser set 12 pack 2 Erasers 5...
# ...             ...                                                ...
# 1753344  B087B9YQ6S  MIER Men s Outdoor Performance Tactical Polo S...
# 1753346  B08TN1F42D  Mens Golf Shirt Moisture Wicking Quick Dry Sho...
# 1753347  B08XX3NL14  SAYFINE 5 Pack Plain Atheletic Shirts for Men ...
# 1753350  B096RXY1VT  Casei Womens Polo Shirts Golf Shirts Quick Dry...
# 1753351  B09BW3YVP8  Men Golf Performance Shirt Moisture Wicking Lo...
#
#                                        product_description  \
# 167175   This pre owned or refurbished product has been...
# 167178   BACK TO BAZIC Our goal is to provide each cust...
# 167179   Emraw Pre Sharpened 2 HB Wood Pencils Pack of ...
# 167184   YOTINO Pre sharpened 2 HB Pencils Pack of 100 ...
# 167187   We made sure that we used high quality materia...
# ...                                                    ...
# 1753344  MIER men s performance short long polo shirt p...
# 1753346  Markalar Men s Classic Quick Drying Golf Polo ...
# 1753347  SAYFINE MENS T SHIRTS GYM T SHIRTS WORKOUT T S...
# 1753350  black friday deals 2021 gifts for men gifts fo...
# 1753351  Golf Tennis has to be one of the most stylish ...
#
#                                       product_bullet_point  \
# 167175   Quiet operation at 1 5 sones Built in thermost...
# 167178   UN SHARPENED 2 PREMIUM PENCILS Each pack comes...
# 167179   PACK OF 8 NUMBER 2 PRESHARPENED BEGINNERS PENC...
# 167184   Convenient Bulk Pack Box of 100 count 2 HB yel...
# 167187   Value For Money Suitable for Kids school penci...
# ...                                                    ...
# 1753344  MIER men s long and short sleeve polo shirt fe...
# 1753346  Quiky dry and Breathable FabricOur Mens Golf S...
# 1753347  VALUE PACK Athletic crew neck and flat lock se...
# 1753350  Quick Dry Moisture WickingWomens polo shirts a...
# 1753351  PERFORMANCE FABRIC Lightweight and Breathable ...
#
#                           product_brand          product_color product_locale  \
# 167175   DELTA ELECTRONICS AMERICAS LTD                  White             us
# 167178                   BAZIC Products               12-count             us
# 167179                            Emraw                 Yellow             us
# 167184                               N2                 Yellow             us
# 167187                            VICGP                  Green             us
# ...                                 ...                    ...            ...
# 1753344                            MIER  Black01- Short Sleeve             us
# 1753346                          SAMERM                  Navy7             us
# 1753347                         SAYFINE         Black (5 Pack)             us
# 1753350                           Casei                  White             us
# 1753351                      JACK SMITH                    Red             us
#
#                                                merged_text  \
# 167175   Delta Electronics RAD80L BreezRadiance 80 CFM ...
# 167178   BAZIC Pencil 2 HB Pencils Latex Free Eraser Wo...
# 167179   Emraw Pre Sharpened Round Primary Size No 2 Ju...
# 167184   YOTINO Pre sharpened Wood Cased 2 HB Pencils B...
# 167187   HB pencils with eraser set 12 pack 2 Erasers 5...
# ...                                                    ...
# 1753344  MIER Men s Outdoor Performance Tactical Polo S...
# 1753346  Mens Golf Shirt Moisture Wicking Quick Dry Sho...
# 1753347  SAYFINE 5 Pack Plain Atheletic Shirts for Men ...
# 1753350  Casei Womens Polo Shirts Golf Shirts Quick Dry...
# 1753351  Men Golf Performance Shirt Moisture Wicking Lo...
#
#                                            merged_metadata  \
# 167175   Delta Electronics RAD80L BreezRadiance 80 CFM ...
# 167178   BAZIC Pencil 2 HB Pencils Latex Free Eraser Wo...
# 167179   Emraw Pre Sharpened Round Primary Size No 2 Ju...
# 167184   YOTINO Pre sharpened Wood Cased 2 HB Pencils B...
# 167187   HB pencils with eraser set 12 pack 2 Erasers 5...
# ...                                                    ...
# 1753344  MIER Men s Outdoor Performance Tactical Polo S...
# 1753346  Mens Golf Shirt Moisture Wicking Quick Dry Sho...
# 1753347  SAYFINE 5 Pack Plain Atheletic Shirts for Men ...
# 1753350  Casei Womens Polo Shirts Golf Shirts Quick Dry...
# 1753351  Men Golf Performance Shirt Moisture Wicking Lo...
#
#                                                   metadata
# 167175   {'product_id': 'B07RH6Z8KW', 'title': 'Delta E...
# 167178   {'product_id': 'B075VXJ9VG', 'title': 'BAZIC P...
# 167179   {'product_id': 'B07G7F6JZ6', 'title': 'Emraw P...
# 167184   {'product_id': 'B087J9MBXJ', 'title': 'YOTINO ...
# 167187   {'product_id': 'B08R8LW1W2', 'title': 'HB penc...
# ...                                                    ...
# 1753344  {'product_id': 'B087B9YQ6S', 'title': 'MIER Me...
# 1753346  {'product_id': 'B08TN1F42D', 'title': 'Mens Go...
# 1753347  {'product_id': 'B08XX3NL14', 'title': 'SAYFINE...
# 1753350  {'product_id': 'B096RXY1VT', 'title': 'Casei W...
# 1753351  {'product_id': 'B09BW3YVP8', 'title': 'Men Gol...
#
# [437953 rows x 10 columns]

# %%
# import dask.dataframe as dd
# from dask.distributed import Client

# # Set up a local Dask client
# client = Client()
# from datapreprocess import clean_text
# processed_data = preprocess_data(df)
# Out:
# C:\Users\prade\AppData\Roaming\Python\Python312\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 50363 instead
#   warnings.warn(
# Rows in Products Data : 1814924
# c:\Users\prade\Documents\M\AmazonProductSearch\datapreprocess.py:9: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# c:\Users\prade\Documents\M\AmazonProductSearch\datapreprocess.py:9: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")

# %%
df.to_csv(os.path.join(en_dataset_dir , 'finalized_dataset_forvectorization.csv' ))
df.to_parquet(os.path.join(en_dataset_dir , 'finalized_dataset_forvectorization.parquet' ))
